# %% [markdown]
# https://studfile.net/preview/7378945/
#
# Практическая работа №3 /ipconfig, ping, tracert, hostname

# %% [markdown]
# ---------------

# %% [markdown]
# # Получение настроек логических сетевых адаптеров персонального компьютера
#
# При помощи команды ipconfig выяснить настройки Вашего активного логического сетевого адаптера
#
# ![image.png](attachment:96d61467-5d49-4f51-bb10-d01d2d16ac0c.png)
#
# так как у Ethernet 2 нет основного шлюза и DNS суффикса подключения - можно предположить что Ethernet 2 - не активен
#
# Ethernet 1 - активен, это

# %% [markdown]
# --------------------

# %% [markdown]
# # Проверка доступа к сетевому шлюзу
# можно попытаться проверить достучавшись до основного шлюза командой, в нашем случае, ping 10.37.22.1
#
# ![image.png](attachment:0ed97cc9-5d09-4b7e-9872-801818a090fa.png)

# %% [markdown]
# --------------------

# %% [markdown]
# # Проверка доступа к интернету
# Доступ к интернету можно проверить командой, например, ping www.dzen.ru
#
# ![image.png](attachment:ca7729e1-8280-4a98-92b0-1f3f1857c64b.png)

# %% [markdown]
# Требуеися поставить
# ![image.png](attachment:image.png)
#
# Включая отключая его можно проверить доступность сайта из того или иного региона
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Требуется в отчете предоставить таблицу для ping теста из 4 стран некоторых сайтов.
# Сайты для проверки
#
# https://www.youtube.com/
#
# https://stackoverflow.com/questions/5898011/jquery-javascript-filtering-html-object-from-ajax-response
#
# https://ru.pinterest.com/
#
# https://www.twitch.tv/terablade
#
# https://w4.cuevana3.ai/
#
# https://kip.eljur.ru/journal-messages-action
#
# http://translit-online.ru/
#
# https://dev.1c-bitrix.ru/community/webdev/user/16002/blog/479/
#
# https://www.youtube.com/watch?v=ZECkSAuy6sg&ab_channel=ТелеканалЮ
#
# https://cloud.mail.ru/public/QaCU/7uQUyPrGD
#
# https://ananasprint.ru/spm/#/
#
# https://mail.rambler.ru/
#
# https://www.mozilla.org/ru/firefox/
#
# https://www.yahoo.com/
#
# https://github.com/IvanSibirevV2/KipFin_Lab_2023_v0_Git0/blob/main/Уп_02_3ПКС_120_220/
#
# https://rutube.ru/video/9eec837c57f774773da9afb1aad1cf93/

# %% [markdown]
# -------------------------

# %% [markdown]
# # Определение пути IP-пакета.
#
# Кстати, вроде как определяет IP4 сайта...
#
# ![image.png](attachment:9c5312ee-5326-490b-b153-ca903708369e.png)
#
# ![image.png](attachment:1245ec5b-9873-4bb8-aa6c-e5084fcf254f.png)

# %% [markdown]
# Требуется определить пути пакетов до сайта и отчитаться об этом
#
# Ответить на вопрос...
#
# До какого сайта наибольшее/наименьшее время пинга и наибольшее/наименьшее колличество узлов .

# %% [markdown]
# ---------------

# %% [markdown]
# # netstat
#
# Выводит перечень сетевых соединений и прослушиваемых портов локального узла
#
# ![image.png](attachment:b5c01ac7-f0b9-4778-b15a-651eb79a628c.png)
#
# ![image.png](attachment:29b64d7e-d241-47ef-b311-ebee019f7eca.png)

# %% [markdown]
# # Получить список маршрутов
#
# ![image.png](attachment:303b0c78-ee63-48c0-803b-40b16023b437.png)

# %% [markdown]
# https://topuch.com/uchebnoj-praktike-dlya-studentov/index6.html
#
# Требуется
#
# Получите список активных TCP-соединений локального компьютера.
#
# Получите список активных TCP-соединений локального компьютера без преобразования IP-адресов в символьные имена DNS.
#
# Получите список прослушиваемых компьютером портов TCP и UDP с и без преобразования IP-адресов в символьные имена DNS.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Таблица трансляций ip/mac адресов
#
# ![image.png](attachment:6643a603-0996-4427-b494-34f6d1a87295.png)
